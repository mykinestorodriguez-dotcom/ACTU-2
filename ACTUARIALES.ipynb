# %% [markdown]
# <a href="https://colab.research.google.com/github/mykinestorodriguez-dotcom/ACTU-2/blob/main/ACTUARIALES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Limpieza de Cartera Actuariales 2

# %%
import pandas as pd
import numpy as np
